# %%
# ——————————————————————————————————————————————————
# IMPORTS
# ——————————————————————————————————————————————————
% delete2/gym_envs/test.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       3 # ——————————————————————————————————————————————————
#       4
#       5
#       6
# ----> 7 from delete2 import main
#       8
#       9 train()
#      10
#
# File /notebooks/delete2/main.py:1
# ----> 1 from epuck_env import EpuckEnv
#       2 from gymnasium.utils.env_checker import check_env
#       5 if __name__ == "__main__":
#       6
#       7     # ==================================================
#       8     # VALIDACIÓN SIN RENDER
#       9     # ==================================================
#
# ModuleNotFoundError: No module named 'epuck_env'
