# %%
# !rm -r logs
# !rm -r models

# %%
# %run delete2/ppo_train.py
train()
# Out:
# Env OK
# Using cpu device
# Logging to ./logs/tensorboard/PPO_1
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -217     |
# | time/              |          |
# |    fps             | 312      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 609         |
# |    ep_rew_mean          | -99.5       |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019473016 |
# |    clip_fraction        | 0.284       |
# ...

# %%
# %run delete2/video.py
