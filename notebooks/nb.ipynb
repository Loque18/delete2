# %%
# ——————————————————————————————————————————————————
# IMPORTS
# ——————————————————————————————————————————————————



from delete2 import train

train()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       3 # ——————————————————————————————————————————————————
#       4
#       5
#       6
# ----> 7 from delete2 import train
#       8
#       9 train()
#      10
#
# File /notebooks/delete2/train.py:10
#       7 from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback
#       8 from stable_baselines3.common.vec_env import DummyVecEnv
# ---> 10 from epuck_env import EpuckEnv
#      13 def make_env():
#      14     env = EpuckEnv(render_mode=None)
#
# ModuleNotFoundError: No module named 'epuck_env'
