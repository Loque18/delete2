# %%
# !rm -r models
# Out:
# rm: cannot remove 'models': No such file or directory

# %%
# %run delete2/train.py
train()
# Out:
# importing from delete2.epuck_env
# Env OK
# Using cuda device
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 get_ipython().run_line_magic('run', 'delete2/train.py')
# ----> 2 train()
#
# File /notebooks/delete2/train.py:68, in train()
#      55 eval_callback = EvalCallback(
#      56     eval_env,
#      57     best_model_save_path="./models/best/",
#    (...)     61     render=False,
#      62 )
#      64 # ==================================================
#      65 # MODEL
#      66 # ==================================================
# ---> 68 model = SAC(
#      69     policy="MlpPolicy",
#      70     env=env,
#      71     learning_rate=3e-4,
#      72     buffer_size=100_000,
#      73     learning_starts=2_000,
#      74     batch_size=256,
#      75     tau=0.005,
#      76     gamma=0.99,
#      77     train_freq=1,
# ...

# %%
# %run delete2/video.py
