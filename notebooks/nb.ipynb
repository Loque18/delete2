# %%
# !rm -r logs
# !rm -r models

# %%
# %run delete2/ppo_train.py
train()

# %%
# %run delete2/video.py
# Out:
# recording video...
# EPISODE END
# terminated: True
# truncated: False
# info: {'robot_x': np.float64(173.0192312735881), 'robot_y': np.float64(183.0621313844298), 'robot_theta': np.float64(-0.22584701503382387), 'step_count': 250, 'reached_goal': np.True_, 'collided': False, 'out_of_bounds': False, 'distance_to_goal': np.float64(7.62284596638029)}
# Video guardado en: ./videos/ppo_epuck_final.mp4
