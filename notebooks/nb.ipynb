# %%
# !rm -r models

# %%
# %run delete2/ppo_train.py
train()
# Out:
# Env OK
# Using cuda device
# Logging to ./logs/tensorboard/PPO_1
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 638      |
# |    ep_rew_mean     | -53.7    |
# | time/              |          |
# |    fps             | 1034     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 783         |
# |    ep_rew_mean          | 10.8        |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011548569 |
# |    clip_fraction        | 0.179       |
# ...

# %%
# %run delete2/video.py
# Out:
# recording video...
# EPISODE END
# terminated: True
# truncated: False
# info: {'robot_x': np.float64(82.02112424609643), 'robot_y': np.float64(106.1449187647762), 'robot_theta': np.float64(1.1853981633974484), 'step_count': 104, 'reached_goal': np.False_, 'collided': True, 'out_of_bounds': False, 'distance_to_goal': np.float64(122.69650817468433)}
# Video guardado en: ./videos/ppo_epuck_final.mp4
