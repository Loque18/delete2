# %%
# ——————————————————————————————————————————————————
# IMPORTS
# ——————————————————————————————————————————————————
from gymnasium.utils.env_checker import check_env


import sys
sys.path.append("..")

from train import train


# ——————————————————————————————————————————————————

train()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 10
#       6
#       7 import sys
#       8 sys.path.append("..")
#       9
# ---> 10 from train import train
#      11
#      12
#      13 # ——————————————————————————————————————————————————
#
# File c:\Users\madri\Documents\maia\16. Robotica\taller2\notebooks\..\train.py:4
#       1 # ——————————————————————————————————————————————————
#       2 # IMPORTS
#       3 # ——————————————————————————————————————————————————
# ----> 4 from stable_baselines3 import SAC
#       5 from stable_baselines3.common.env_checker import check_env
#       6 from stable_baselines3.common.monitor import Monitor
#
# ModuleNotFoundError: No module named 'stable_baselines3'
