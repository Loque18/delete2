# %%
# !rm -r logs
# !rm -r models

# %%
# %run delete2/train.py
train()

# %%
# %run delete2/video.py
# Out:
# recording video...
# EPISODE END
# terminated: False
# truncated: True
# info: {'robot_x': np.float64(84.92895396346165), 'robot_y': np.float64(36.59467039188429), 'robot_theta': np.float64(0.2480251868559291), 'step_count': 1000, 'reached_goal': np.False_, 'collided': False, 'out_of_bounds': False, 'distance_to_goal': np.float64(172.05694509229758)}
# Video guardado en: ./videos/sac_epuck_final.mp4
