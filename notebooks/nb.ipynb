# %%
# !rm -r logs
# !rm -r models

# %%
# %run delete2/ppo_train.py
train()
# Out:
# Env OK
# Using cuda device
# Logging to ./logs/tensorboard/PPO_1
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 547      |
# |    ep_rew_mean     | -120     |
# | time/              |          |
# |    fps             | 362      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 728          |
# |    ep_rew_mean          | -97.4        |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0125054885 |
# |    clip_fraction        | 0.136        |
# ...

# %%
# %run delete2/video.py
