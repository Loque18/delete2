# %%
# !rm -r logs
# !rm -r models

# %%
# %run delete2/train.py
train()
# Out:
# Env OK
# Using cuda device
# Logging to ./logs/tensorboard/SAC_1
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 911      |
# |    ep_rew_mean     | 134      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 151      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 3645     |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 0.0276   |
# |    ent_coef        | 0.617    |
# |    ent_coef_loss   | -1.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1644     |
# ---------------------------------
# Eval num_timesteps=5000, episode_reward=-78.19 +/- 244.92
# Episode length: 314.00 +/- 343.20
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 314      |
# |    mean_reward     | -78.2    |
# | time/              |          |
# ...

# %%
# %run delete2/video.py
