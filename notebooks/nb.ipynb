# %%
# !rm -r models
# Out:
# rm: cannot remove 'models': No such file or directory

# %%
# %run delete2/train.py
train()
# Out:
# importing from delete2.epuck_env
# Env OK
# Using cuda device
# Logging to ./logs/tensorboard/SAC_1
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 819      |
# |    ep_rew_mean     | 504      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 313      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3275     |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 0.446    |
# |    ent_coef        | 0.7      |
# |    ent_coef_loss   | -0.849   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1274     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 571      |
# |    ep_rew_mean     | 740      |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 222      |
# ...

# %%
# %run delete2/video.py
# Out:
# Frame shape: [[[ 80  80  80]
#   [ 80  80  80]
#   [ 80  80  80]
#   ...
#   [ 80  80  80]
#   [ 80  80  80]
#   [ 80  80  80]]
#
#  [[ 80  80  80]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [ 80  80  80]]
#
#  [[ 80  80  80]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [ 80  80  80]]
#
#  ...
#
#  [[ 80  80  80]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [ 80  80  80]]
#
#  [[ 80  80  80]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [ 80  80  80]]
#
#  [[ 80  80  80]
#   [ 80  80  80]
#   [ 80  80  80]
#   ...
#   [ 80  80  80]
#   [ 80  80  80]
#   [ 80  80  80]]]
# Video guardado en: ./videos/sac_epuck_eval.mp4
