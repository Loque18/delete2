# %%
# ——————————————————————————————————————————————————
# IMPORTS
# ——————————————————————————————————————————————————
from gymnasium.utils.env_checker import check_env


import sys
sys.path.append("..")

from train import train


# ——————————————————————————————————————————————————
# env example
# ——————————————————————————————————————————————————


env = EpuckEnv(render_mode="human")
check_env(env.unwrapped)

obs, info = env.reset(seed=42)
print("check_env OK")
print("obs shape:", obs.shape)
print("initial obs:", obs)

for _ in range(10):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    print(reward, terminated, truncated, info)

    if terminated or truncated:
        obs, info = env.reset()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 18
#      14 # env example
#      15 # ——————————————————————————————————————————————————
#      16
#      17
# ---> 18 env = EpuckEnv(render_mode="human")
#      19 check_env(env.unwrapped)
#      20
#      21 obs, info = env.reset(seed=42)
#
# File c:\Users\madri\Documents\maia\16. Robotica\taller2\notebooks\..\epuck_env.py:45, in EpuckEnv.__init__(self, render_mode, arena_size, max_steps, goal, robot_start, obstacle_radius)
#      42 self.prev_dist_to_goal = 0.0
#      44 # action space
# ---> 45 self.action_space = spaces.Box(
#      46     low=np.array([-1.0, -1.0], dtype=np.float32),
#      47     hight=np.array([1.0, 1.0], dtype=np.float32),
#      48     shape=(2,),
#      49     dtype=np.float32
#      50 )
#      52 # 8 sensors + x,y,theta al objetivo
#      53 self.observation_space = spaces.Box(
#      54     low=-1.0,
#      55     high=1.0,
#      56     shape=(11,),
#      57     dtype=np.float32
#      58 )
#
# TypeError: Box.__init__() got an unexpected keyword argument 'hight'
