# %%
# ——————————————————————————————————————————————————
# IMPORTS
# ——————————————————————————————————————————————————
# %run delete2/train.py

train()
# Out:
# importing from delete2.epuck_env
# Env OK
# Using cuda device
# Logging to ./logs/tensorboard/SAC_4
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 769      |
# |    ep_rew_mean     | 446      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 336      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 3075     |
# | train/             |          |
# |    actor_loss      | -11.8    |
# |    critic_loss     | 1.05     |
# |    ent_coef        | 0.744    |
# |    ent_coef_loss   | -0.708   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1074     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 560      |
# |    ep_rew_mean     | 724      |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 213      |
# ...
